# %% [markdown]
# <a href="https://colab.research.google.com/github/luhcrodrigues/Estudos_Python/blob/main/C%C3%B3pia_de_Python_Fundamentos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #listas

# %% [markdown]
# Armazena sequencia de valotres ordenados,elemento ou item,contendo índices e são ordenados porque cada valor tem uma posicão

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
